# %%
from langchain.chat_models import ChatOpenAI

# temperature -> 모델의 창의력 수치 0.1 은 별로 창의적이지 않은 상태 0.9는 매우 창의적인 상태
chat = ChatOpenAI(temperature=0.1)

# %%
from langchain.schema import HumanMessage , AIMessage , SystemMessage

# %%
messages = [
    SystemMessage(content="You are a geography expert. And you only reply in Korean."),
    AIMessage(content="안녕하세요! 저는 aaaa입니다!"),
    HumanMessage(content="What is the distance between Mexico and Thailand. Also, what is your name?")
]

chat.predict_messages(messages=messages)
# Out:
# AIMessage(content='멕시코와 태국 사이의 거리는 대략 16,000km입니다. 제 이름은 aaaa입니다. 어떻게 도와드릴까요?')
